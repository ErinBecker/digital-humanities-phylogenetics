# %% [markdown]
# # Old Babylonian Lists of Trees and Wooden Objects
# This notebook will use data scraped from [DCCLT](http://oracc.org/dcclt) with the notebooks [Save ORACC HTML files](https://github.com/niekveldhuis/Digital-Assyriology/blob/master/Scrape-Oracc/Save%20Oracc%20HTML%20files.ipynb) and [Scrape Oracc](https://github.com/niekveldhuis/Digital-Assyriology/blob/master/Scrape-Oracc/Scrape%20Oracc.ipynb), using the input file [ob_lists_wood.txt](https://github.com/ErinBecker/digital-humanities-phylogenetics/blob/master/data/text_ids/ob_lists_wood.txt). The input file lists all the Text IDs of Old Babylonian lists of trees and wooden objects currently in DCCLT, as well as the composite text of the Nippur version. Text IDs consist of a P plus a six-digit number (commonly referred to as P-number) that is recognized by [ORACC](http://oracc.org) and by [CDLI](http://cdli.ucla.edu) and that has become the de-facto standard in Assyriology. [CDLI](http://cdli.ucla.edu) provides metadata (provenience, period, publication, museum number, etc) for each text.  Composite text IDs consist of a Q plus a six-digit number.
#
# The raw data are placed in the directory [data/raw](https://github.com/ErinBecker/digital-humanities-phylogenetics/tree/master/data/raw). Each text has a separate file named dcclt_P######.txt (or dcclt_Q######.txt). These are comma-separated files with the fields id_text, text_name, l_no, text.
#
# | field         | description                     |
# |-----------	|------------------------------------------------------------------------------------------------------------------------------------------------------	|
# | text_id   	| allows creation of a link to the online edition in [DCCLT](http://oracc.org/dcclt) and/or to the images and metadata in [CDLI](http://cdli.ucla.edu) 	|
# | text_name 	| a reference to a text (publication or museum number) that is recognizable by Assyriologists                                                          	|
# | l_no      	| line number: obverse/reverse, column number, line number (e.g. o ii 16')                                                                                  	|
# | text      	| Sumerian words in lemmatized form (e.g. lugal[king]N)                                                                                                     	|

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Create list of Text Files
# The input list used for scraping is used here again to create a list of file names.

# %%
textlist = '../data/text_ids/ob_lists_wood.txt'
with open(textlist) as f:
    text_ids = f.readlines()
text_ids = [id.strip() for id in text_ids]
# strip in case there are any accidental spaces
path = "../data/raw/"
filenames = [path + id.replace('/', '_') + '.txt' for id in text_ids]
filenames[:5]
# Out:
# ['../data/raw/dcclt_Q000039.txt',
#  '../data/raw/dcclt_P117395.txt',
#  '../data/raw/dcclt_P117404.txt',
#  '../data/raw/dcclt_P128345.txt',
#  '../data/raw/dcclt_P224980.txt']

# %% [markdown]
# # Open Files
# Open each file and create a Dataframe in Pandas and create a list of Dataframes. Concatenate that list into a single Dataframe and re-index.

# %%
list_ = [pd.read_csv(file_,index_col=None, header=0) for file_ in filenames]
df = pd.concat(list_).reset_index(drop=True)

# %%
df
# Out:
#             id_text                           text_name    l_no  \
# 0     dcclt/Q000039                    OB Nippur Ura 01       1
# 1     dcclt/Q000039                    OB Nippur Ura 01       2
# 2     dcclt/Q000039                    OB Nippur Ura 01       3
# 3     dcclt/Q000039                    OB Nippur Ura 01       4
# 4     dcclt/Q000039                    OB Nippur Ura 01       5
# 5     dcclt/Q000039                    OB Nippur Ura 01       6
# 6     dcclt/Q000039                    OB Nippur Ura 01      6a
# 7     dcclt/Q000039                    OB Nippur Ura 01      6b
# 3995  dcclt/P492330  AO 05401 (MSL SS 1 97-98) [OB Ura]  o ii 2
# 3996  dcclt/P492330  AO 05401 (MSL SS 1 97-98) [OB Ura]  o ii 3
# 3997  dcclt/P492330  AO 05401 (MSL SS 1 97-98) [OB Ura]  o ii 4
# 3998  dcclt/P492330  AO 05401 (MSL SS 1 97-98) [OB Ura]  o ii 5
# 3999  dcclt/P492330  AO 05401 (MSL SS 1 97-98) [OB Ura]  o ii 6
# 4000  dcclt/P492330  AO 05401 (MSL SS 1 97-98) [OB Ura]  o ii 7
# 4001  dcclt/P492330  AO 05401 (MSL SS 1 97-98) [OB Ura]  o ii 8
# 4002  dcclt/P492330  AO 05401 (MSL SS 1 97-98) [OB Ura]  r i 4'
#
#                                                    text
# 0                                sux:taškarin[boxwood]N
# 1                                        sux:esi[tree]N
# 2                                      sux:ŋešnu[tree]N
# 3                                      sux:halub[tree]N
# 4                                     sux:šagkal[tree]N
# 5                                    sux:ŋešgana[tree]N
# 6               sux:ŋešgana[tree]N sux:babbar[white]V/i
# 7                sux:ŋešgana[tree]N sux:giggi[black]V/i
# 8                    sux:ŋeš[tree]N sux:giggi[black]V/i
# 9                                     sux:ŋeštin[vine]N
# 10                               sux:ŋeštinkira[berry]N
# 11                               sux:ŋeštinkaʾa[grape]N
# 12                             sux:ŋeštinguruma[~vine]N
# 13                                        sux:peš[fig]N
# 14                                   sux:hašhur[apple]N
# 15                sux:hašhur[apple]N sux:kur[mountain]N
# 16                                     sux:šedug[tree]N
# 17                                      sux:šenu[tree]N
# 18                                      sux:šeše[tree]N
# 19                                 sux:šinig[tamarisk]N
# 20             sux:šinig[tamarisk]N sux:dili[single]V/i
# 21              sux:šinig[tamarisk]N sux:kur[mountain]N
# 22                                  sux:šaršabid[tree]N
# 23                   sux:mes[tree]N sux:šaršabid[tree]N
# 24                                       sux:lam[tree]N
# 25                                        sux:eš[tree]N
# 26                                      sux:usuh[tree]N
# 27                    sux:usuh[tree]N sux:tur[small]V/i
# 28      sux:usuh[tree]N sux:pa[branch]N sux:kud[cut]V/t
# 29        sux:usuh[tree]N sux:a[water]N sux:de[pour]V/t
# ...                                                 ...
# 3973                                   sux:lamgal[nut]N
# 3974                                   sux:lamtur[nut]N
# 3975                     sux:ma[ship]N sux:Ninurta[1]DN
# 3976                     sux:ma[ship]N sux:sig[weak]V/i
# 3977                                sux:gigir[chariot]N
# 3978        sux:ŋirigub[footstool]N sux:gigir[chariot]N
# 3979                                    sux:šenu[tree]N
# 3980                                   sux:šedug[tree]N
# 3981                                    sux:šeše[tree]N
# 3982                                     sux:saŋ[head]N
# 3983  sux:saŋkul[bolt]N sux:la[hang]V/t akk-x-oldbab...
# 3984  sux:subur[chariot]N akk-x-oldbab:narkabtu[char...
# 3985                 sux:ŋeš[tree]N sux:gilim[cross]V/t
# 3986  sux:ŋeš[tree]N sux:sal[thin]V/i akk-x-oldbab:i...
# 3987  sux:ŋeš[tree]N sux:bar[cvve]V/t akk-x-oldbab:i...
# 3988  sux:ŋeš[tree]N sux:šuš[cut]V/t akk-x-oldbab:hu...
# 3989         sux:ŋešed[key]N akk-x-oldbab:namzāqu[key]N
# 3990  sux:ŋeš[tree]N sux:rugu[withstand]V/t akk-x-ol...
# 3991  sux:ŋeš[tree]N akk-x-oldbab:iṣu[tree]N akk-x-o...
# 3992  akk-x-oldbab:nipṣu[smashing]N akk-x-oldbab:luq...
# 3993                        akk-x-oldbab:burussu[bung]N
# 3994                                 sux:tukul[weapon]N
# 3995                                 sux:tukul[weapon]N
# 3996                sux:tukul[weapon]N sux:šeŋ[rain]V/i
# 3997  sux:tukul[weapon]N sux:saŋ[head]N sux:gaz[kill...
# 3998  sux:tukul[weapon]N sux:saŋ[head]N sux:ninnu[fi...
# 3999                   sux:tukul[weapon]N sux:Suen[1]DN
# 4000            sux:tukul[weapon]N sux:mahdi[exalted]AJ
# 4001  sux:tukul[weapon]N sux:saŋ[head]N sux:gaz[kill...
# 4002                            sux:dibdib[waterclock]N
#
# [4003 rows x 4 columns]

# %% [markdown]
# # Create Expressions
# A line in a lexical text may contain more than one word. Usually a list is divided into sections by keyword, for instance:
#
# | text                	| translation                      	|
# |---------------------	|----------------------------------	|
# | {ŋeš}gigir          	| chariot                          	|
# | {ŋeš}e₂ gigir       	| chariot cabin                    	|
# | {ŋeš}e₂ usan₃ gigir 	| storage box for the chariot whip 	|
# | {ŋeš}gaba gigir     	| breastwork of a chariot          	|
#
# The comparison between different versions of the list may be based on
#
# * presence or absence of entries
# * order of entries in a section
# * order of sections in the document
# * spelling of words
#
# In order to look at entries (rather than words), words in an entry are connected by asterisks (*).

# %%
df['entries'] = df['text'].replace(' ', '*')
df
# Out:
#             id_text                           text_name    l_no  \
# 0     dcclt/Q000039                    OB Nippur Ura 01       1
# 1     dcclt/Q000039                    OB Nippur Ura 01       2
# 2     dcclt/Q000039                    OB Nippur Ura 01       3
# 3     dcclt/Q000039                    OB Nippur Ura 01       4
# 4     dcclt/Q000039                    OB Nippur Ura 01       5
# 5     dcclt/Q000039                    OB Nippur Ura 01       6
# 6     dcclt/Q000039                    OB Nippur Ura 01      6a
# 7     dcclt/Q000039                    OB Nippur Ura 01      6b
# 8     dcclt/Q000039                    OB Nippur Ura 01       7
# 9     dcclt/Q000039                    OB Nippur Ura 01       8
# 10    dcclt/Q000039                    OB Nippur Ura 01       9
# 11    dcclt/Q000039                    OB Nippur Ura 01      10
# 12    dcclt/Q000039                    OB Nippur Ura 01      11
# 13    dcclt/Q000039                    OB Nippur Ura 01      12
# 14    dcclt/Q000039                    OB Nippur Ura 01      13
# 15    dcclt/Q000039                    OB Nippur Ura 01      14
# 16    dcclt/Q000039                    OB Nippur Ura 01      15
# 17    dcclt/Q000039                    OB Nippur Ura 01      16
# 18    dcclt/Q000039                    OB Nippur Ura 01      17
# 19    dcclt/Q000039                    OB Nippur Ura 01      18
# 20    dcclt/Q000039                    OB Nippur Ura 01      19
# 21    dcclt/Q000039                    OB Nippur Ura 01      20
# 22    dcclt/Q000039                    OB Nippur Ura 01      21
# 23    dcclt/Q000039                    OB Nippur Ura 01      22
# 24    dcclt/Q000039                    OB Nippur Ura 01      23
# 25    dcclt/Q000039                    OB Nippur Ura 01      24
# 26    dcclt/Q000039                    OB Nippur Ura 01      25
# 7                sux:ŋešgana[tree]N sux:giggi[black]V/i
# 8                    sux:ŋeš[tree]N sux:giggi[black]V/i
# 9                                     sux:ŋeštin[vine]N
# 10                               sux:ŋeštinkira[berry]N
# 11                               sux:ŋeštinkaʾa[grape]N
# 12                             sux:ŋeštinguruma[~vine]N
# 13                                        sux:peš[fig]N
# 14                                   sux:hašhur[apple]N
# 15                sux:hašhur[apple]N sux:kur[mountain]N
# 16                                     sux:šedug[tree]N
# 17                                      sux:šenu[tree]N
# 18                                      sux:šeše[tree]N
# 19                                 sux:šinig[tamarisk]N
# 20             sux:šinig[tamarisk]N sux:dili[single]V/i
# 21              sux:šinig[tamarisk]N sux:kur[mountain]N
# 22                                  sux:šaršabid[tree]N
# 23                   sux:mes[tree]N sux:šaršabid[tree]N
# 24                                       sux:lam[tree]N
# 25                                        sux:eš[tree]N
# 26                                      sux:usuh[tree]N
# 27                    sux:usuh[tree]N sux:tur[small]V/i
# 28      sux:usuh[tree]N sux:pa[branch]N sux:kud[cut]V/t
# 29        sux:usuh[tree]N sux:a[water]N sux:de[pour]V/t
# ...                                                 ...
# 3973                                   sux:lamgal[nut]N
# 3974                                   sux:lamtur[nut]N
# 3975                     sux:ma[ship]N sux:Ninurta[1]DN
# 3976                     sux:ma[ship]N sux:sig[weak]V/i
# 3977                                sux:gigir[chariot]N
# 3978        sux:ŋirigub[footstool]N sux:gigir[chariot]N
# 3979                                    sux:šenu[tree]N
# 3980                                   sux:šedug[tree]N
# 3981                                    sux:šeše[tree]N
# 3982                                     sux:saŋ[head]N
# 3983  sux:saŋkul[bolt]N sux:la[hang]V/t akk-x-oldbab...
# 3984  sux:subur[chariot]N akk-x-oldbab:narkabtu[char...
# 3985                 sux:ŋeš[tree]N sux:gilim[cross]V/t
# 3986  sux:ŋeš[tree]N sux:sal[thin]V/i akk-x-oldbab:i...
# 3987  sux:ŋeš[tree]N sux:bar[cvve]V/t akk-x-oldbab:i...
# 3988  sux:ŋeš[tree]N sux:šuš[cut]V/t akk-x-oldbab:hu...
# 3989         sux:ŋešed[key]N akk-x-oldbab:namzāqu[key]N
# 3990  sux:ŋeš[tree]N sux:rugu[withstand]V/t akk-x-ol...
# 3991  sux:ŋeš[tree]N akk-x-oldbab:iṣu[tree]N akk-x-o...
# 3992  akk-x-oldbab:nipṣu[smashing]N akk-x-oldbab:luq...
# 3993                        akk-x-oldbab:burussu[bung]N
# 3994                                 sux:tukul[weapon]N
# 3995                                 sux:tukul[weapon]N
# 3996                sux:tukul[weapon]N sux:šeŋ[rain]V/i
# 3997  sux:tukul[weapon]N sux:saŋ[head]N sux:gaz[kill...
# 3998  sux:tukul[weapon]N sux:saŋ[head]N sux:ninnu[fi...
# 3999                   sux:tukul[weapon]N sux:Suen[1]DN
# 4000            sux:tukul[weapon]N sux:mahdi[exalted]AJ
# 4001  sux:tukul[weapon]N sux:saŋ[head]N sux:gaz[kill...
# 4002                            sux:dibdib[waterclock]N
#
#                                                 entries
# 0                                sux:taškarin[boxwood]N
# 1                                        sux:esi[tree]N
# 2                                      sux:ŋešnu[tree]N
# 3                                      sux:halub[tree]N
# 4                                     sux:šagkal[tree]N
# 5                                    sux:ŋešgana[tree]N
# 6               sux:ŋešgana[tree]N sux:babbar[white]V/i
# 7                sux:ŋešgana[tree]N sux:giggi[black]V/i
# 8                    sux:ŋeš[tree]N sux:giggi[black]V/i
# 9                                     sux:ŋeštin[vine]N
# 10                               sux:ŋeštinkira[berry]N
# 11                               sux:ŋeštinkaʾa[grape]N
# 12                             sux:ŋeštinguruma[~vine]N
# 13                                        sux:peš[fig]N
# 14                                   sux:hašhur[apple]N
# 15                sux:hašhur[apple]N sux:kur[mountain]N
# 16                                     sux:šedug[tree]N
# 17                                      sux:šenu[tree]N
# 18                                      sux:šeše[tree]N
# 19                                 sux:šinig[tamarisk]N
# 20             sux:šinig[tamarisk]N sux:dili[single]V/i
# 21              sux:šinig[tamarisk]N sux:kur[mountain]N
# 22                                  sux:šaršabid[tree]N
# 23                   sux:mes[tree]N sux:šaršabid[tree]N
# 24                                       sux:lam[tree]N
# 25                                        sux:eš[tree]N
# 26                                      sux:usuh[tree]N
# 27                    sux:usuh[tree]N sux:tur[small]V/i
# 28      sux:usuh[tree]N sux:pa[branch]N sux:kud[cut]V/t
# 29        sux:usuh[tree]N sux:a[water]N sux:de[pour]V/t
# ...                                                 ...
# 3973                                   sux:lamgal[nut]N
# 3974                                   sux:lamtur[nut]N
# 3975                     sux:ma[ship]N sux:Ninurta[1]DN
# 3976                     sux:ma[ship]N sux:sig[weak]V/i
# 3977                                sux:gigir[chariot]N
# 3978        sux:ŋirigub[footstool]N sux:gigir[chariot]N
# 3979                                    sux:šenu[tree]N
# 3980                                   sux:šedug[tree]N
# 3981                                    sux:šeše[tree]N
# 3982                                     sux:saŋ[head]N
# 3983  sux:saŋkul[bolt]N sux:la[hang]V/t akk-x-oldbab...
# 3984  sux:subur[chariot]N akk-x-oldbab:narkabtu[char...
# 3985                 sux:ŋeš[tree]N sux:gilim[cross]V/t
# 3986  sux:ŋeš[tree]N sux:sal[thin]V/i akk-x-oldbab:i...
# 3987  sux:ŋeš[tree]N sux:bar[cvve]V/t akk-x-oldbab:i...
# 3988  sux:ŋeš[tree]N sux:šuš[cut]V/t akk-x-oldbab:hu...
# 3989         sux:ŋešed[key]N akk-x-oldbab:namzāqu[key]N
# 3990  sux:ŋeš[tree]N sux:rugu[withstand]V/t akk-x-ol...
# 3991  sux:ŋeš[tree]N akk-x-oldbab:iṣu[tree]N akk-x-o...
# 3992  akk-x-oldbab:nipṣu[smashing]N akk-x-oldbab:luq...
# 3993                        akk-x-oldbab:burussu[bung]N
# 3994                                 sux:tukul[weapon]N
# 3995                                 sux:tukul[weapon]N
# 3996                sux:tukul[weapon]N sux:šeŋ[rain]V/i
# 3997  sux:tukul[weapon]N sux:saŋ[head]N sux:gaz[kill...
# 3998  sux:tukul[weapon]N sux:saŋ[head]N sux:ninnu[fi...
# 3999                   sux:tukul[weapon]N sux:Suen[1]DN
# 4000            sux:tukul[weapon]N sux:mahdi[exalted]AJ
# 4001  sux:tukul[weapon]N sux:saŋ[head]N sux:gaz[kill...
# 4002                            sux:dibdib[waterclock]N
#
# [4003 rows x 5 columns]
